# %% [markdown]
# ## Analisando a dinâmica da serie temporal e o comportamento do preço ##

# %%
import quandl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dol = quandl.get('BCB/1', start_date = '2016-01-01', end_date = '2019-01-01').reset_index(drop=True)

# %%
plt.plot(dol)

# %%
dol.tail(10)
# Out:
#       Value
# 740  3.9121
# 741  3.8997
# 742  3.8907
# 743  3.8443
# 744  3.8671
# 745  3.8855
# 746  3.9258
# 747  3.9330
# 748  3.8748
# 749  3.8748

# %%
r = dol.rolling(window=21)
plt.plot(dol, 'k-', alpha = 0.5)
plt.plot(r.mean(), 'r-')

# %%
#logaritmo serie de retorno

dol_ret = np.log(dol).diff().dropna()
plt.plot(dol_ret)

# %%
# recosntruindo a série de preço Pt a partir dos retornos Xt
# p_(t-1) exp (x_t)
doll= np.cumprod(np.r_[dol.values[0], np.exp(dol_ret.values.reshape(len(dol_ret)))])
plt.plot(doll)

# %%
#ver comportamento da série de retorno
dol_ret.hist(bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff8ffdb5048>]],
#       dtype=object)

# %%
#média movel dos retornos
#oscilando bem menos
r = dol_ret.rolling(window=21)
plt.plot(dol_ret, 'k-', alpha = 0.5)
plt.plot(r.mean(), 'r-')

# %%
#desvio padrão
plt.plot(dol_ret, 'k-', alpha = 0.5)
plt.plot(r.std(), 'r-')

# %%
#Modelo de auto regressão = Xt = Y + TETA... VER NO VIDEO

# %%
#statsmodels é usada pra explicar fenomenos de forma estatistica
#TSA time series analisis
import statsmodels.tsa as tsa
import statsmodels.api as sm

# %%
#ARMA auto regressos 
#mle maximum likelyhood extimator
model = sm.tsa.ARMA(dol_ret.as_matrix(), (1, 0)).fit(trend = 'c')
print (model.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  749
# Model:                     ARMA(1, 0)   Log Likelihood                2458.478
# Method:                       css-mle   S.D. of innovations              0.009
# Date:                Mon, 01 Jul 2019   AIC                          -4910.956
# Time:                        13:45:02   BIC                          -4897.100
# Sample:                             0   HQIC                         -4905.617
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.554e-05      0.000     -0.163      0.870      -0.001       0.001
# ar.L1.y        0.0244      0.037      0.669      0.504      -0.047       0.096
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           40.9488           +0.0000j           40.9488            0.0000
# -----------------------------------------------------------------------------
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:3: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
model.params
# Out:
# array([-5.55401256e-05,  2.44207567e-02])

# %%
dol_ar_proc = tsa.arima_process.ArmaProcess(np.r_[1, -model.params], [1])

# %%
dol_ar_sim = dol_ar_proc.generate_sample(len(dol_ret))*model.resid.std()

# %%
#real
plt.plot(dol_ret)

# %%
#simulado
plt.plot(dol_ar_sim)

# %%
doll = np.cumprod(np.r_[dol.values[1], np.exp(dol_ar_sim)])

# %%
#real
plt.plot(dol)
#simulado = predito
plt.plot(doll)
plt.show()

# %%
#residuos
#quase tudo virou residuo
plt.plot(dol_ret)
plt.plot(model.resid)
plt.show()

# %%
#testando GARCH
from arch import arch_model

# %%
am = arch_model(dol_ret*100, p=1, q=1)

# %%
res = am.fit(disp='off')

# %%
print(res.summary())
# Out:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  Value   R-squared:                      -0.000
# Mean Model:             Constant Mean   Adj. R-squared:                 -0.000
# Vol Model:                      GARCH   Log-Likelihood:               -964.000
# Distribution:                  Normal   AIC:                           1936.00
# Method:            Maximum Likelihood   BIC:                           1954.48
#                                         No. Observations:                  749
# Date:                Mon, Jul 01 2019   Df Residuals:                      745
# Time:                        14:04:02   Df Model:                            4
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu            -0.0184  3.012e-02     -0.610      0.542 [-7.741e-02,4.067e-02]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.6002      0.154      3.900  9.631e-05   [  0.299,  0.902]
# alpha[1]       0.3035      0.119      2.557  1.055e-02 [7.091e-02,  0.536]
# beta[1]        0.0000      0.258      0.000      1.000   [ -0.505,  0.505]
# ==========================================================================
#
# Covariance estimator: robust

# %%
# Mu é a média do retorno

# %%
# simulando garch
# entender o comportamento da variavel
# simulando o modelo matematico
def simulate_garch(params, nobs, var=0):
    e = np.random.randn(nobs)
    var = np.zeros(len(e)) + var
    x = np.zeros(len(e))
    
    for t in range(len(e)):
        var[t] = params[1] + params[2] * x[t-1]**2 + params[3] * var[t-1]
        x[t] = params[0] + e[t] * np.sqrt(var[t])
        
    return x

# %%
res.params
# Out:
# mu         -0.018372
# omega       0.600156
# alpha[1]    0.303517
# beta[1]     0.000000
# Name: params, dtype: float64

# %%
dol_am_sim = simulate_garch(res.params, len(dol_ret))/100

# %%
#retorno dolar
plt.plot(dol_ret)
#retorno dolar simulado = predito
plt.plot(dol_am_sim)
plt.show()

# %%
#retorno dolar
plt.plot(dol_ar_sim)
#retorno dolar simulado = predito
plt.plot(dol_am_sim)
plt.show()

# %%
doll = np.cumprod(np.r_[dol.values[1], np.exp(dol_am_sim)])

# %%
#real
plt.plot(dol)
#simulado = predito
plt.plot(doll)
plt.show()

# %%
#predição
dol.tail(252).plot()
paths = np.zeros((100,21))
for i in range(100):
    dol_am_sim = simulate_garch(res.params, 20)/100
    path = np.cumprod(np.r_[dol.values[-1], np.exp(dol_am_sim)])
    paths[i,:] = path
    plt.plot(range(999, 999+21), path, '-g', alpha = 0.25)
plt.plot(range(999, 999+21), np.mean(paths, 0), '-r')

# %%
dol.tail(252).plot()
for i in range(100):
    dol_am_sim = simulate_garch(res.params, 20)/100
    path = np.cumprod(np.r_[dol.values[-1], np.exp(dol_am_sim)])
    paths[i,:] = path
    plt.plot(range(999, 999+21), path, '-g', alpha = 0.25)
plt.plot(range(999, 999+21), np.mean(paths, 0), '-r');

# %%
for i in range(100):
    dol_am_sim = simulate_garch(res.params, 20)/100
    path = np.cumprod(np.r_[dol.values[-1], np.exp(dol_am_sim)])
    paths[i,:] = path
    plt.plot(range(999, 999+21), path, '-g', alpha = 0.25)
plt.plot(range(999, 999+21), np.mean(paths, 0), '-r')

# %%
dol_am_sim
# Out:
# array([-0.00520691,  0.0126304 , -0.00737081,  0.0058101 ,  0.00309714,
#        -0.00407538, -0.01620524,  0.01163913, -0.00298574, -0.00369641,
#        -0.0074337 ,  0.00694014, -0.01486377, -0.00670704,  0.00324351,
#        -0.00296679, -0.00873233,  0.01424391, -0.00594236, -0.01075532])

# %%
int = simulate_garch(res.params, 20)

# %%
int
# Out:
# array([-0.4465853 ,  0.2332749 ,  0.37521025, -0.1479058 ,  0.5751741 ,
#        -0.83125755,  0.51997183, -0.70181555, -1.34339494, -0.05910685,
#        -0.37544352, -0.54419611,  0.26238704,  0.20979117,  0.59544914,
#        -0.27620972, -0.72100201, -0.08570082, -0.09871362, -0.68910149])
