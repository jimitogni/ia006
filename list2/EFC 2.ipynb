# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('two_moons.csv')
data.head()
# Out:
#    Unnamed: 0       x_1       x_2    y
# 0           0  2.064430  0.546069  1.0
# 1           1  1.762473 -0.062689  1.0
# 2           2 -0.245490  1.068868  0.0
# 3           3 -0.174630  0.183882  1.0
# 4           4  0.452110 -0.406512  1.0

# %%
scatter_plot = plt.scatter(data['x_1'], data['x_2'], alpha=0.5, c=data['y'])
plt.show()
