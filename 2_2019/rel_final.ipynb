# %% [markdown]
# ## IA006 - EFC1 - 2s2019
#
# $~$
#
# ## Jimi Togni - RA 226359
#
# ### Parte 1 - Teórica
# ----

# %% [markdown]
# ### **Exercício 1**
#
# $~$
#
# **Distribuição:**
#
# |  X / Y   |  Y=0 |  Y=1  | TMarg. X |
# |:--------:|:----:|:-----:|:--------:|
# |  X = 0   |  1/6 |  3/8  |  13/24   |
# |  X = 1   |  1/8 |  1/3  |  11/24   |
# | TMarg. Y | 7/24 | 17/24 |    1     |
#
# $~$
# $~$

# %% [markdown]
# ## --------------------------
# **a)** $P(X)$ e $P(Y)$
#
#
#  - $P(X=x) = \{\frac{13}{24}, \frac{11}{24}\}$
#
#
#  - $P(Y=y) = \{\frac{7}{24}, \frac{17}{24}\}$
#
# $~$

# %% [markdown]
# ## --------------------------
# **b)** $P(X=0|Y=0)$
#
# $P\frac{P({X=0}, {Y=0})}{P(Y=0)} = \frac{1}{6}\times\frac{24}{7} = \frac{24}{42} = \frac{4}{7}$
#
# $P(X=0,Y=0) = P(X=0)P(Y=0) => \frac{1}{6} = \frac{13}{24}\times\frac{7}{24} => \frac{1}{6} \neq \frac{91}{576}$
#
#
# $P\frac{P({X=1}, {Y=0})}{P(Y=0)} = \frac{1}{8}\times\frac{24}{7} = \frac{24}{56} = \frac{3}{7}$
#
# $~$
# - $P(X=0|Y=0) = \frac{4}{7}$
#
# $~$
# $~$
#
# ---

# %% [markdown]
# ## --------------------------
# **c)** $E[X]$ e $E[Y]$
#
# $E[X] = \sum_kx_kP(x_k)$
#
# $E[X] = 0 \times \frac{13}{24} + 1 \times \frac{11}{24}$
#
# $E[Y] = 0 \times \frac{7}{24} + 1 \times \frac{17}{24}$
#
#
# - $E[X] = \frac{11}{24}$
#
#
# - $E[Y] = \frac{17}{24}$
#
#
# ---

# %% [markdown]
# ## --------------------------
# d) São independentes? Por quê?
#
# X e Y NÃO são independentes, pois:
#
# $P(X,Y) = P(X)P(Y)$
#
# Portanto:
#
# $P(X=x,Y=0) = P(X=x)P(Y=0)$
#
# Por fim temos:
#
# $P(X=0,Y=0) = P(X=0)P(Y=0) => \frac{1}{6} = \frac{13}{24}\times\frac{7}{24} => \frac{1}{6} \neq \frac{91}{576}$
#
# $P(X=1,Y=0) = P(X=1)P(Y=0) => \frac{1}{8} = \frac{11}{24}\times\frac{7}{24} => \frac{1}{8} \neq \frac{77}{576}$
#
# ---

# %% [markdown]
# ## --------------------------
#
# ### **Exercício 2**
#
# $~$
#
# **Distribuição:**
#
# |  X / Y   |  Y=0 |  Y=1  | TMarg. X |
# |:--------:|:----:|:-----:|:--------:|
# |   X=0    |   0  |  1/4  |   1/4    |
# |   X=1    |  3/8 |  3/8  |   3/4    |
# | TMarg. Y |  3/8 |  5/8  |    1     |
#
# $~$
# $~$

# %% [markdown]
# ## --------------------------
# a) $H(X), H(Y), H(X,Y)$
#
# Sendo: $H(X) = -\sum_x p(x)log_2[p(x)]$
#
# $H(X) = H(\frac{1}{4}, \frac{3}{4})$
#
# $H(X) = -((\frac{1}{4} \times log_2[\frac{1}{4}]) + (\frac{3}{4} \times log_2[\frac{3}{4}]))$
#
# $H(X) = -((\frac{1}{4} \times -2) + (\frac{3}{4} (log_2[3]-2)))$
#
# $H(X) = -((-\frac{1}{2}) + (\frac{3}{4} (log_2[3]-2)))$
#
# $H(X) = 0.8112$
#
# $~$
#
# $H(Y) = H(\frac{3}{8}, \frac{5}{8})$
#
# $H(Y) = -((\frac{3}{8} \times log_2[\frac{3}{8}]) + (\frac{5}{8} \times log_2[\frac{5}{8}]))$
#
# $H(Y) = -((\frac{3}{8} (log_2(3)-3)) + (\frac{5}{8} (log_2(5)-3)))$
#
# $H(Y) = 0.9544$
#
# $~$
# $~$
#
# A entropia conjunta de $H(X, Y)$
#
# Sendo: $H(X, Y) = -\sum_x\sum_y p(x, y) log_2[p(x, y)]$
#
# $H(X, Y) = -((\frac{1}{4} log_2(\frac{1}{4}))+(\frac{3}{8} log_2(\frac{3}{8}))+(\frac{3}{8} log_2(\frac{3}{8})))$
#
# $H(X, Y) = 1.5612$
#
# **Resposta:**
#
# As entropias são:
#
# $H(X) = 0.8112$
#
# $H(Y) = 0.9544$
#
# $H(X, Y) = 1.5612$
#
# $~$
# $~$

# %% [markdown]
# ## --------------------------
# b) $H(X|Y)$ e $H(Y|X)$
#
# $H(Y|X) = -\sum_x\sum_y p(x, y) log_2[p(y|x)]$
#
# A formula da informação condicial:
#
# $H(Y|X) = H(X, Y) - H(X)$
#
# $H(X|Y) = H(X, Y) - H(Y)$
#
# $~$
#
# $P(Y=1 | X=0) = \frac{P(X=0, Y=1)}{P(X)} => \frac{1}{4}\times\frac{4}{1} = 1$
#
# $P(Y=0 | X=1) = \frac{P(X=1, Y=0)}{P(X)} => \frac{3}{8}\times\frac{4}{3} = \frac{1}{2}$
#
# $P(Y=1 | X=1) = \frac{P(X=1, Y=1)}{P(X)} = \frac{1}{2}$
#
# $~$
# $~$
#
# $H(Y|X) = -( (\frac{1}{4} log_2(1)) + (\frac{3}{8} log_2(\frac{1}{2})) + (\frac{3}{8} log_2(\frac{1}{2})) )$
#
# $H(Y|X) = -( (\frac{3}{8} \times -1) + (\frac{3}{8} \times -1) )$
#
# $H(Y|X) = -( (-\frac{3}{8}) + (-\frac{3}{8}) )$
#
# $H(Y|X) = 0.75$
#
# $~$
#
# $H(X|Y) = 1.5612 - 0.9544$
#
# $H(X|Y) = 0.6068$
#
# **Resposta:**
#
# $H(Y|X) = 0.75$
#
# $H(X|Y) = 0.6068$
#
#
# $~$
# $~$
#
# ----

# %% [markdown]
# ## --------------------------
# c) $I(X, Y)$
#
# A informação mútua é dada por:
#
# $I(X, Y) = H(X) - H(X|Y)$
#
# Portanto,
#
# $I(X, Y) = 0.8112 - 0.6068$
#
# $I(X, Y) = 0.2044$
#
#
# **Resposta:**
#
# $I(X, Y) = 0.2044$
#
# ---

# %% [markdown]
# ## --------------------------
#
# ### **Exercício 3**

# %%
import csv
import time
from datetime import datetime
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **A) Dados**
#
# $C_1 =>\mu = -1, \sigma^2 = 1$
#
# $C_2 =>\mu = 1, \sigma^2 = 1$

# %% [markdown]
# **Função de probabilidade de densidade da Distribuição Gausiana é:**
#
# $f(x|\mu,\sigma^2) = \frac{1}{\sqrt{2\pi\sigma^2}} exp(-\frac{(x - \mu)^2)}{2\sigma^2})$
#
# **MLE:**
#
# $\theta_{MLE} = argmax_{\theta} log [p(x|\theta)]$
#
# Sendo $\theta = (\mu, \sigma^2)$,
#
# **MLE é calculada por:**
#
# $L(x|\mu,\sigma^2) = log [p(x|\mu,\sigma^2)]$
#
# **estimador de maxima verossimilhança:**
#
# $L(x|\mu, \sigma^2) = -\frac{n}{2} log (2\pi\sigma^2) - \frac{1}{2\sigma^2}\sum_{i=1}^{n}(x - \mu)^2$
#
#
# **para $n=1$:**
#
# $L(x|\mu=-1,\sigma^2=1) = -\frac{1}{2} log (2\pi) - \frac{1}{2} (x + 1)^2$
#
# $L(x|\mu=-1,\sigma^2=1) = -\frac{1}{2} log (2\pi) - \frac{1}{2} (x - 1)^2$
#
# $~$

# %% [markdown]
# #### -----------
# Levando em consideração os dados acima $x = 0$, as equações terão valores iguais, definindo a fronteira onde se encontram no ponto x 0.
#
# Verificando a discrepância com outros valores.
#
# $L(x=1|\mu=-1,\sigma^2=1) = -\frac{1}{2} log (2\pi) - \frac{1}{2} (1 + 1)^2$
#
# $L(x=1|\mu=-1,\sigma^2=1) = -0.9189 - \frac{1}{2} (2)^2$
#
# $L(x=1|\mu=-1,\sigma^2=1) = -0.9189 - 2$
#
# $L(x=1|\mu=-1,\sigma^2=1) = -2.9189$
#
# $~$
#
# $L(x=1|\mu=1,\sigma^2=1) = -\frac{1}{2} log (2\pi) - \frac{1}{2} (1 - 1)^2$
#
# $L(x=1|\mu=1,\sigma^2=1) = -0.9189 - \frac{1}{2} (0)^2$
#
# $L(x=1|\mu=1,\sigma^2=1) = -0.9189$
#
#
# $~$
#
# Com $x=0$:
#
# $L(x=0|\mu=1,\sigma^2=1) = -\frac{1}{2} log (2\pi) - \frac{1}{2} (0 - 1)^2$
#
# $L(x=0|\mu=1,\sigma^2=1) = -0.9189 - \frac{1}{2} (-1)^2$
#
# $L(x=0|\mu=1,\sigma^2=1) = -1.4189$
#
# $~$
#
# $L(x=0|\mu=-1,\sigma^2=1) = -\frac{1}{2} log (2\pi) - \frac{1}{2} (0 - (-1))^2$
#
# $L(x=0|\mu=-1,\sigma^2=1) = -0.9189 - \frac{1}{2} (1)^2$
#
# $L(x=0|\mu=-1,\sigma^2=1) = -1.4189$
#
# $~$
#
# **Portanto:**
#
# Portanto, podemos concluir que amostras menores que 0 podem ser classificadas como sendo da classe $C_1$ e valores acima de 0 para da classe $C_2$, e 0 o ponto de confusão entre elas.
#
# $C_1 : x < 0$
#
# $C_2 : x > 0$
#
# $~$
# $~$

# %%
def pdf(x, m, s):
    return (1/(np.sqrt(2*np.pi*s))) * np.exp(-((np.power((x-(m)), 2) / 2*s)))

def intersection(m1, s1, m2, s2, p1=1, p2=1):
    pdf1 = pdf(0, m1, s1)
    pdf2 = pdf(0, m2, s2)
    return (np.log(pdf1 / pdf2) + np.log(p1/p2)) / 2

m1, m2, s1, s2 = -1, 1, 1, 1
N = 500
space = np.linspace(-4, 5, N)
px1 = norm(m1, np.sqrt(s1)).pdf(space)
px2 = norm(m2, np.sqrt(s2)).pdf(space)

fig = plt.figure(1, figsize=(17, 5))
plt.subplot(121)
plt.title('Distribuição de Probabilidades das Classes')
plt.annotate("intersecção", 
            xy=(0, 0.24),
            xycoords='data',
            xytext=(0.5, 0.3),
            textcoords='data',
            arrowprops=dict(arrowstyle="->",connectionstyle="arc3"))
plt.xlabel('x')
plt.ylabel('y(x)')
plt.xticks(np.arange(-6, 7))
plt.yticks(np.round(np.linspace(0, 0.45, 9), 2))
plt.plot(space, px1, color='C0', markersize=3, label='$C_1 : \mu$=-1, $\sigma^2$=1')
plt.plot(space, px2, color='C1', markersize=3, label='$C_2 : \mu$=1, $\sigma^2$=1')
plt.axvline(x=intersection(m1, m2, s1, s2), label='intersecção', ls='--', color='g')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ------------------
#
# **B)** $P(C_1) = 0,7, P(C_2) = 0,3$
#
# **MAP:**
#
# $\theta_{MAP} = argmax_{\theta} log [p(x|\theta)] + log [p(\theta)]$
#
# Sendo $\theta = (\mu, \sigma^2)$ e para o caso da classe $C_1$:
#
# $f(x|\mu=-1, \sigma^2=1) = log [p(x|\mu=-1, \sigma^2=1)] + log [p(\mu=-1, \sigma^2=1)]$
#
# para $x=0$:
#
# $log [p(x=0|\mu=-1, \sigma^2=1)] = -1.4189$
#
# $p(\mu=-1, \sigma^2=1) = 0.7$
#
# **portanto:**
#
# $f(x=0|\mu=-1, \sigma^2=1) = -1.4189 + log[0.7]$
#
# $f(x=0|\mu=-1, \sigma^2=1) = -1.7755$
#
# **e para a classe $C_2$:**
#
# $f(x=0|\mu=1, \sigma^2=1) = -1.4189 + log[0.3]$
#
# $f(x=0|\mu=1, \sigma^2=1) = -2.6228$
#
# $~$
#
# **Resultados**:
#
# Pode-se notar que, para a amostra 0, a região de indecisão fica menos aparente.
#
# Dado o enunciado, com as distribuições uniformes, média equidistantes e variâncias iguais a média, podemos calcular o ponto de intersecção, indiferente da densidade de probabilidades, com valores a posteriori:
#
#
# $\frac{P(C_1∣x)}{P(C_2∣x)} = log\frac{f1(x)}{f2(x)} + log\frac{P(C_1)}{P(C_2)}$
#
# $\frac{P(C_1∣x=-1)}{P(C_2∣x=1)} = log\frac{f1(x=-1)}{f2(x=1)} + log\frac{P(C_1)}{P(C_2)}$
#
# $\frac{P(C_1∣x=-1)}{P(C_2∣x=1)} = log\frac{0.3989}{0.3989} + log\frac{0.7}{0.3}$
#
# $\frac{P(C_1∣x=-1)}{P(C_2∣x=1)} = 0 + 0.8472$
#
# **Para as duas classes:**
#
# $\frac{P(C_1∣x=-1)}{P(C_2∣x=1)} = \frac{0.8472}{2}$
#
# $\frac{P(C_1∣x=-1)}{P(C_2∣x=1)} = 0.4236$
#
# $~$
#
# **Fronteira de decisão será igual a $0.4236$.**
# $~$
#
# Portanto:
#
# $C_1 : x < 0.436$
#
# $C_2 : x > 0.436$

# %%
m1, m2, s1, s2, p1, p2 = -1, 1, 1, 1, .7, .3
N = 500
space = np.linspace(-4, 5, N)
px1 = norm(m1, np.sqrt(s1)).pdf(space) * p1
px2 = norm(m2, np.sqrt(s2)).pdf(space) * p2

fig = plt.figure(1, figsize=(17, 5))
plt.subplot(121)
plt.title('Gráfico da Distribuição de Probabilidades de cada Classe')
plt.annotate("intersecção", 
            xy=(0.436, 0.1),
            xycoords='data',
            xytext=(0.6, 0.2),
            textcoords='data',
            arrowprops=dict(arrowstyle="->",connectionstyle="arc3"))
plt.xlabel('x')
plt.ylabel('y(x)')
plt.xticks(np.arange(-6, 7))
plt.yticks(np.round(np.linspace(0, 0.45, 9), 2))
plt.plot(space, px1, color='C0', markersize=3, label='$C1 : \mu$=-1, $\sigma^2$=1')
plt.plot(space, px2, color='C1', markersize=3, label='$C2 : \mu$=1, $\sigma^2$=1')
plt.axvline(x=intersection(m1, s1, m2, s2, p1, p2), label='intersecção', ls='--', color='g')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ![Tslambs4.png](attachment:Tslambs4.png)

# %% [markdown]
# ![TsMeans4.png](attachment:TsMeans4.png)

# %% [markdown]
# ![model_rmse4.png](attachment:model_rmse4.png)

# %% [markdown]
# ![model_test4.png](attachment:model_test4.png)

# %% [markdown]
# ---

# %% [markdown]
# ![Tslambs2.png](attachment:Tslambs2.png)

# %% [markdown]
# ![TsMeans2.png](attachment:TsMeans2.png)

# %% [markdown]
# ![model_test2.png](attachment:model_test2.png)
